# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from utils.ticker_data import get_stock_data, windowed_dfs

# %%
df = get_stock_data("^NSEI")
df.head()
# Out:
# c:\Users\borishan\Desktop\ml\code\ml_vs_baseline_reits\utils\ticker_data.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start.strftime('%Y-%m-%d'), end=end.strftime('%Y-%m-%d'))
# [*********************100%***********************]  1 of 1 completed
#         Date          Open          High           Low         Close  Volume  \
# 0 2024-07-11  24396.550781  24402.650391  24193.750000  24315.949219  306400
# 1 2024-07-12  24387.949219  24592.199219  24331.150391  24502.150391  325800
# 2 2024-07-15  24587.599609  24635.050781  24522.750000  24586.699219  305400
# 3 2024-07-16  24615.900391  24661.250000  24587.650391  24613.000000  283200
# 4 2024-07-18  24543.800781  24837.750000  24504.449219  24800.849609  350900
#
#     Returns
# 0 -0.000350
# 1  0.007628
# 2  0.003445
# 3  0.001069
# 4  0.007603

# %%
X, y = windowed_dfs(df, size = 10)
print(X.shape, y.shape)
print(X.head())
print(y.head())
# Out:
# (237, 9) (237, 2)
#    9-days-before  8-days-before  7-days-before  6-days-before  5-days-before  \
# 0   24315.949219   24502.150391   24586.699219   24613.000000   24800.849609
# 1   24502.150391   24586.699219   24613.000000   24800.849609   24530.900391
# 2   24586.699219   24613.000000   24800.849609   24530.900391   24509.250000
# 3   24613.000000   24800.849609   24530.900391   24509.250000   24479.050781
# 4   24800.849609   24530.900391   24509.250000   24479.050781   24413.500000
#
#    4-days-before  3-days-before  2-days-before  1-days-before
# 0   24530.900391   24509.250000   24479.050781   24413.500000
# 1   24509.250000   24479.050781   24413.500000   24406.099609
# 2   24479.050781   24413.500000   24406.099609   24834.849609
# 3   24413.500000   24406.099609   24834.849609   24836.099609
# 4   24406.099609   24834.849609   24836.099609   24857.300781
#         Date         Close
# 0 2024-07-26  24834.849609
# 1 2024-07-29  24836.099609
# 2 2024-07-30  24857.300781
# ...

# %%
for i in range(5 ):
    plt.plot(X.iloc[i].values, lw = 1)
plt.show()
